# %% [markdown]
# # Description of the Problem and Discussion of the Background (Introduction Section)

# %% [markdown]
# ### North Dallas-Fort Worth Metroplex, TX relocation and restuarant prospects

# %% [markdown]
# Per the [Dallas Cultural Map](https://dallas.culturemap.com/news/city-life/01-09-20-dfw-lead-population-growth-2020-2029-cushman-wakefield/), following a decade of eye-popping population growth, Dallas-Fort-Worth is expected in this decade to once again lead the nation’s metro areas for the number of new residents.
# New data from commercial real estate services company Cushman & Wakefield shows DFW gained 1,349,378 residents from 2010 through 2019. In terms of the number of new residents tallied during the past decade, DFW ranked first among U.S. metro areas, the data indicates.
# From 2020 through 2029, DFW is projected to tack on another 1,393,623 residents, Cushman & Wakefield says. For the second decade in a row, that would be the highest number of new residents for any metro area, the company says.
# Also per [bizournals](https://www.bizjournals.com/dallas/news/2019/11/21/study-660-companies-moving-facilities-out-of.html), some 660 companies moved 765 facilities out of California in the past two years, and Dallas-Fort Worth has been the beneficiary of many of the relocations, according to a new report. The departures from the Golden State between January 2018 and now involve corporate headquarters, manufacturing facilities, data centers, research hubs, software and engineering centers and a few warehouses.
#
# With all this information at hand a team is looking for a good location in the North Dallas-Fort-Worth Metroplex to setup their restaurant where they can make the most profit

# %% [markdown]
# # Target audience for this analyses

# %% [markdown]
#   * Business men looking at capitalizing on the growth of the North Dallas region to open restaurants or other business
#   * People looking homes near the North Dallas business district who would like to leave near areas with lots of restaurants

# %% [markdown]
# # A description of the data and how it will be used to solve the problem.

# %% [markdown]
# Two data sources where used for this analyses, first data source is made up of all the zip codes, zip code names and population in the Collin and Dnton counties which are both located in north Dallas where most of the migration has taken place and also where majurity of the companies that moved to the Dallas-Firt-Worth Metroplex are located.
# The second data source contains the zip codes, zip code names and both latitude and longitude of all zip codes.
# Both data sources where merged on the zip code and zip code names.

# %% [markdown]
# **Obtain the Data and analysing the neighborhoods**

# %% [markdown]
#   * Pandas will be used to scrap the data of the counties from [zipdatamaps](https://www.zipdatamaps.com/list-of-zip-codes-in-texas.php)
#   * The csv for the second data source will be downloaded from [zipdatamaps](https://www.zipdatamaps.com/list-of-zip-codes-in-texas.php)
#   * Two counties (Collin and Denton) will be selected for the analyses
#   * Use Foresquare Data to obtain info about restaurants
#   * Data Visualization and Statistical Analysis
#   * Analysis Using Clustering, Specially K-Means Clustering
#     - Maximize the number of clusters.
#     - Visualization using Chloropleth Map
#   * Compare the Neighborhoods to Find the Best Place for Starting up a Restaurant

# %% [markdown]
# # Data preparation

# %% [markdown]
# ### Import necessary libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# **Use panda to get data from [zipdatamaps](https://www.zipdatamaps.com/list-of-zip-codes-in-texas.php)**

# %% [markdown]
# We will create 2 dataframes then concatenate them in one main dataframe which will contain all the zipcodes for both counties

# %%
collin_county_df = pd.read_html("https://www.zipdatamaps.com/collin-tx-county-zipcodes")
denton_county_df = pd.read_html("https://www.zipdatamaps.com/denton-tx-county-zipcodes")
collin_county_df = collin_county_df[1]
collin_county_df.columns = ['ZIP Code', 'ZIP Code Name', 'Population', 'Type']
denton_county_df = denton_county_df[1]
denton_county_df.columns = ['ZIP Code', 'ZIP Code Name', 'Population', 'Type']

# %%
collin_county_df.head()
# Out:
#    ZIP Code ZIP Code Name  Population        Type
# 0   75002.0         Allen     63140.0  Non-Unique
# 1   75009.0        Celina      8785.0  Non-Unique
# 2   75013.0         Allen     30347.0  Non-Unique
# 3   75023.0         Plano     45452.0  Non-Unique
# 4   75024.0         Plano     36039.0  Non-Unique

# %%
denton_county_df.head()
# Out:
#    ZIP Code ZIP Code Name  Population        Type
# 0   75007.0    Carrollton     51624.0  Non-Unique
# 1   75009.0        Celina      8785.0  Non-Unique
# 2   75010.0    Carrollton     21607.0  Non-Unique
# 3   75019.0       Coppell     38666.0  Non-Unique
# 4   75022.0  Flower Mound     22545.0  Non-Unique

# %% [markdown]
# Concatenating both dataframes

# %%
frames = [collin_county_df, denton_county_df]

# %%
north_dfw_df = pd.concat(frames, ignore_index=True)

# %% [markdown]
# Removing duplicate zip codes

# %%
north_dfw_df.drop_duplicates(subset=['ZIP Code'], inplace=True)

# %%
north_dfw_df.dropna(inplace=True)

# %% [markdown]
# To reduce how much memory we would use later, we will need to drop all zip codes with zero population as they will definitely not be needed for our analyses.

# %%
north_dfw_df = north_dfw_df[north_dfw_df['Population'] != 0]

# %% [markdown]
# We will be droping column 'Type' as it wont be need for this project

# %%
north_dfw_df.drop(columns=['Type'], axis=1, inplace=True)

# %%
north_dfw_df.head()
# Out:
#    ZIP Code ZIP Code Name  Population
# 0   75002.0         Allen     63140.0
# 1   75009.0        Celina      8785.0
# 2   75013.0         Allen     30347.0
# 3   75023.0         Plano     45452.0
# 4   75024.0         Plano     36039.0

# %% [markdown]
# ### Get zip code data for Dallas-Fort-Worth from [opendatasoft](https://public.opendatasoft.com/explore/dataset/us-zip-code-latitude-and-longitude/table/?refine.state=TX)

# %%
zip_df = pd.read_csv('us-zip-code-latitude-and-longitude.csv', sep=';', usecols=['Zip','City', 'State', 'Latitude', 'Longitude'])

# %%
zip_df = zip_df.rename(columns={'Zip': 'ZIP Code', 'City': 'ZIP Code Name'})

# %%
zip_df.head()
# Out:
#    ZIP Code ZIP Code Name State   Latitude  Longitude
# 0     75475      Randolph    TX  33.485315  -96.25525
# 1     75757       Bullard    TX  32.136787  -95.36710
# 2     78650        McDade    TX  30.283941  -97.23563
# 3     75010    Carrollton    TX  33.030556  -96.89328
# 4     76054         Hurst    TX  32.858398  -97.17681

# %%
north_dfw_df['ZIP Code'] = north_dfw_df['ZIP Code'].astype('int32')

# %%
north_dfw_df = pd.merge(left=north_dfw_df, right=zip_df, on=['ZIP Code', 'ZIP Code Name'])
north_dfw_df
# Out:
#     ZIP Code ZIP Code Name  Population State   Latitude  Longitude
# 0      75002         Allen     63140.0    TX  33.092846 -96.624470
# 1      75009        Celina      8785.0    TX  33.327927 -96.761290
# 2      75013         Allen     30347.0    TX  33.106582 -96.694020
# 3      75023         Plano     45452.0    TX  33.054671 -96.735060
# 4      75024         Plano     36039.0    TX  33.077070 -96.798590
# 5      75025         Plano     50926.0    TX  33.086868 -96.745040
# 6      75034        Frisco     72723.0    TX  33.143792 -96.839380
# 7      75035        Frisco     47553.0    TX  33.130086 -96.781770
# 8      75069      McKinney     34108.0    TX  33.195073 -96.603630
# 9      75070      McKinney     74734.0    TX  33.212203 -96.675220
# 10     75074         Plano     44622.0    TX  33.028921 -96.681020
# 11     75075         Plano     33262.0    TX  33.024721 -96.740380
# 12     75078       Prosper     10592.0    TX  33.240766 -96.799440
# 13     75080    Richardson     44009.0    TX  32.969523 -96.740930
# 14     75082    Richardson     21182.0    TX  32.993405 -96.659010
# 15     75087      Rockwall     28145.0    TX  32.933820 -96.454460
# 16     75093         Plano     47187.0    TX  33.035050 -96.804920
# 17     75094         Plano     20579.0    TX  33.009681 -96.611130
# 18     75098         Wylie     48197.0    TX  33.011975 -96.536070
# 19     75166         Lavon      3070.0    TX  33.022051 -96.436010
# 20     75173        Nevada      4353.0    TX  33.048275 -96.421530
# 21     75252        Dallas     24112.0    TX  32.998132 -96.790880
# 22     75287        Dallas     49004.0    TX  32.998786 -96.844360
# 23     75407     Princeton     14120.0    TX  33.145720 -96.496640
# 24     75409          Anna     11831.0    TX  33.356094 -96.519070
# 25     75424    Blue Ridge      3297.0    TX  33.321604 -96.395020
# 26     75442  Farmersville      8858.0    TX  33.171899 -96.350960
# 27     75454       Melissa      5699.0    TX  33.277317 -96.573450
# 28     75495   Van Alstyne      7095.0    TX  33.426635 -96.563700
# 29     75164     Josephine       671.0    TX  33.065217 -96.311520
# 30     75007    Carrollton     51624.0    TX  33.005420 -96.897730
# 31     75010    Carrollton     21607.0    TX  33.030556 -96.893280
# 32     75019       Coppell     38666.0    TX  32.967341 -96.986560
# 33     75022  Flower Mound     22545.0    TX  33.024778 -97.102060
# 34     75028  Flower Mound     42226.0    TX  33.033214 -97.059650
# 35     75056    The Colony     47852.0    TX  33.081421 -96.889570
# 36     75057    Lewisville     12900.0    TX  33.048670 -96.993210
# 37     75065   Lake Dallas     10748.0    TX  33.126350 -97.025250
# 38     75067    Lewisville     60982.0    TX  33.020118 -97.007710
# 39     75068    Little Elm     34934.0    TX  33.173008 -96.954850
# 40     75077    Lewisville     35330.0    TX  33.075138 -97.052900
# 41     76052        Haslet     15995.0    TX  32.972998 -97.355920
# 42     76078         Rhome      8572.0    TX  33.072675 -97.473000
# 43     76092     Southlake     26669.0    TX  32.946678 -97.145230
# 44     76177    Fort Worth      4891.0    TX  32.949819 -97.314060
# 45     76201        Denton     27107.0    TX  33.226598 -97.130610
# 46     76205        Denton     18510.0    TX  33.161560 -97.103760
# 47     76207        Denton     10579.0    TX  33.236827 -97.169410
# 48     76208        Denton     19782.0    TX  33.198442 -97.060780
# 49     76209        Denton     24018.0    TX  33.235520 -97.112743
# 50     76226        Argyle     18419.0    TX  33.105309 -97.162940
# 51     76227        Aubrey     22141.0    TX  33.274761 -96.994570
# 52     76247        Justin     13098.0    TX  33.087040 -97.303840
# 53     76249          Krum      7194.0    TX  33.270036 -97.248590
# 54     76258   Pilot Point      6659.0    TX  33.385645 -96.952130
# 55     76259        Ponder      4618.0    TX  33.187644 -97.296760
# 56     76262       Roanoke     27648.0    TX  33.000177 -97.218710
# 57     76266        Sanger     13495.0    TX  33.358871 -97.189440
# 58     76272   Valley View      4745.0    TX  33.482548 -97.122590

# %% [markdown]
# We would select only the cities within North Dallas thats located close to the business district in Plano

# %%
north_dfw_df = north_dfw_df.loc[north_dfw_df['ZIP Code Name'].isin(['Plano', 'Frisco', 'Richardson', 'Allen', 'The Colony', 'Carrollton', 'McKinney'])]

# %%
north_dfw_df.reset_index(drop=True, inplace=True)

# %%
north_dfw_df.shape
# Out:
# (18, 6)

# %%
north_dfw_df
# Out:
#     ZIP Code ZIP Code Name  Population State   Latitude  Longitude
# 0      75002         Allen     63140.0    TX  33.092846  -96.62447
# 1      75013         Allen     30347.0    TX  33.106582  -96.69402
# 2      75023         Plano     45452.0    TX  33.054671  -96.73506
# 3      75024         Plano     36039.0    TX  33.077070  -96.79859
# 4      75025         Plano     50926.0    TX  33.086868  -96.74504
# 5      75034        Frisco     72723.0    TX  33.143792  -96.83938
# 6      75035        Frisco     47553.0    TX  33.130086  -96.78177
# 7      75069      McKinney     34108.0    TX  33.195073  -96.60363
# 8      75070      McKinney     74734.0    TX  33.212203  -96.67522
# 9      75074         Plano     44622.0    TX  33.028921  -96.68102
# 10     75075         Plano     33262.0    TX  33.024721  -96.74038
# 11     75080    Richardson     44009.0    TX  32.969523  -96.74093
# 12     75082    Richardson     21182.0    TX  32.993405  -96.65901
# 13     75093         Plano     47187.0    TX  33.035050  -96.80492
# 14     75094         Plano     20579.0    TX  33.009681  -96.61113
# 15     75007    Carrollton     51624.0    TX  33.005420  -96.89773
# 16     75010    Carrollton     21607.0    TX  33.030556  -96.89328
# 17     75056    The Colony     47852.0    TX  33.081421  -96.88957

# %% [markdown]
# Now we get the latitude and longtitude of Plano, Texas which is the business destrict of North Dallas

# %%
geolocator = Nominatim(user_agent="dfw_explorer")
address = 'Plano, TX'

location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Dallas-Fort-Worth are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Dallas-Fort-Worth are 33.0136764, -96.6925096.

# %% [markdown]
# Use folium to show the zip codes we want to explore

# %%
# create map of Dallas-Fort-Worth using latitude and longitude values
map_dfw = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(north_dfw_df['Latitude'], north_dfw_df['Longitude'], north_dfw_df['ZIP Code Name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_dfw)  
    
map_dfw
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Define Foursquare Credentials and Version**

# %%
CLIENT_ID = 'your-client-ID' # your Foursquare ID
CLIENT_SECRET = 'your-client-secret' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: your-client-ID
# CLIENT_SECRET:your-client-secret

# %% [markdown]
# **Explore zip codes in North Dallas-Fort-Worth, Texas**

# %% [markdown]
# Get all venues within 10miles from the zip code

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=30000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['ZIP Code Name', 
                  'ZIP Code Latitude', 
                  'ZIP Code Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
north_dfw_venues = getNearbyVenues(names=north_dfw_df['ZIP Code Name'],
                                   latitudes=north_dfw_df['Latitude'],
                                   longitudes=north_dfw_df['Longitude']
                                  )
# Out:
# Allen
# Allen
# Plano
# Plano
# Plano
# Frisco
# Frisco
# McKinney
# McKinney
# Plano
# Plano
# Richardson
# Richardson
# Plano
# Plano
# Carrollton
# Carrollton
# The Colony

# %%
# Create a Data-Frame out of it to Concentrate Only on Restaurants 

north_dfw_Venues_only_restaurant = north_dfw_venues[north_dfw_venues['Venue Category']\
                                                          .str.contains('Restaurant')].reset_index(drop=True)
north_dfw_Venues_only_restaurant.index = np.arange(1, len(north_dfw_Venues_only_restaurant)+1)
print ("Shape of the Data-Frame with Venue Category only Restaurant: ", north_dfw_Venues_only_restaurant.shape)
north_dfw_Venues_only_restaurant.head()
# Out:
# Shape of the Data-Frame with Venue Category only Restaurant:  (468, 7)
#   ZIP Code Name  ZIP Code Latitude  ZIP Code Longitude  \
# 1         Allen          33.092846           -96.62447
# 2         Allen          33.092846           -96.62447
# 3         Allen          33.092846           -96.62447
# 4         Allen          33.092846           -96.62447
# 5         Allen          33.092846           -96.62447
#
#                             Venue  Venue Latitude  Venue Longitude  \
# 1                     Chick-fil-A       33.129069       -96.650699
# 2  Pho Crystal Vietnamese Cuisine       33.130105       -96.643033
# 3       Mio Nonno Wood Fire Pizza       33.129612       -96.674279
# 4       Black Walnut Café - Allen       33.129348       -96.675808
# 5              Yanni's Greek Cafe       33.011051       -96.610110
#
#           Venue Category
# 1   Fast Food Restaurant
# 2  Vietnamese Restaurant
# 3     Italian Restaurant
# 4    American Restaurant
# 5       Greek Restaurant

# %%
## Show in Map the Top Rated Restaruants in the Top 5 Districts

map_restaurants = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the Venues based on the Major Districts
Districts = ['Plano', 'Frisco', 'Richardson', 'Allen', 'The Colony', 'Carrollton', 'McKinney']

x = np.arange(len(Districts))

rainbow = ['#00ff00', '#ff00ff','#0000ff','#ffa500' ,'#ff0000', '#000000', '#ffffff']

# add markers to the map
# markers_colors = []
for lat, lon, poi, distr in zip(north_dfw_Venues_only_restaurant['Venue Latitude'], 
                                  north_dfw_Venues_only_restaurant['Venue Longitude'], 
                                  north_dfw_Venues_only_restaurant['Venue Category'], 
                                  north_dfw_Venues_only_restaurant['ZIP Code Name']):
    label = folium.Popup(str(poi) + ' ' + str(distr), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=7,
        popup=label,
        color=rainbow[Districts.index(distr)-1],
        fill=True,
        fill_color=rainbow[Districts.index(distr)-1],
        fill_opacity=0.3).add_to(map_restaurants)
       
map_restaurants
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
north_dfw_Venues_only_restaurant.head()
# Out:
#   ZIP Code Name  ZIP Code Latitude  ZIP Code Longitude  \
# 1         Allen          33.092846           -96.62447
# 2         Allen          33.092846           -96.62447
# 3         Allen          33.092846           -96.62447
# 4         Allen          33.092846           -96.62447
# 5         Allen          33.092846           -96.62447
#
#                             Venue  Venue Latitude  Venue Longitude  \
# 1                     Chick-fil-A       33.129069       -96.650699
# 2  Pho Crystal Vietnamese Cuisine       33.130105       -96.643033
# 3       Mio Nonno Wood Fire Pizza       33.129612       -96.674279
# 4       Black Walnut Café - Allen       33.129348       -96.675808
# 5              Yanni's Greek Cafe       33.011051       -96.610110
#
#           Venue Category
# 1   Fast Food Restaurant
# 2  Vietnamese Restaurant
# 3     Italian Restaurant
# 4    American Restaurant
# 5       Greek Restaurant

# %%
north_dfw_Venues_only_restaurant.groupby('ZIP Code Name').count()
# Out:
#                ZIP Code Latitude  ZIP Code Longitude  Venue  Venue Latitude  \
# ZIP Code Name
# Allen                         50                  50     50              50
# Carrollton                    53                  53     53              53
# Frisco                        55                  55     55              55
# McKinney                      48                  48     48              48
# Plano                        185                 185    185             185
# Richardson                    52                  52     52              52
# The Colony                    25                  25     25              25
#
#                Venue Longitude  Venue Category
# ZIP Code Name
# Allen                       50              50
# Carrollton                  53              53
# Frisco                      55              55
# McKinney                    48              48
# Plano                      185             185
# Richardson                  52              52
# The Colony                  25              25

# %%
print('There are {} uniques categories.'.format(len(north_dfw_Venues_only_restaurant['Venue Category'].unique())))
# Out:
# There are 20 uniques categories.

# %% [markdown]
# ## Analyze Each Neighborhood

# %%
# one hot encoding
north_dfw_onehot = pd.get_dummies(north_dfw_Venues_only_restaurant[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
north_dfw_onehot['ZIP Code Name'] = north_dfw_Venues_only_restaurant['ZIP Code Name'] 

# move neighborhood column to the first column
col = north_dfw_onehot.pop("ZIP Code Name")
north_dfw_onehot.insert(0, col.name, col)

north_dfw_onehot.head()
# Out:
#   ZIP Code Name  American Restaurant  Brazilian Restaurant  \
# 1         Allen                    0                     0
# 2         Allen                    0                     0
# 3         Allen                    0                     0
# 4         Allen                    1                     0
# 5         Allen                    0                     0
#
#    Cajun / Creole Restaurant  Chinese Restaurant  Fast Food Restaurant  \
# 1                          0                   0                     1
# 2                          0                   0                     0
# 3                          0                   0                     0
# 4                          0                   0                     0
# 5                          0                   0                     0
#
#    Greek Restaurant  Italian Restaurant  Japanese Restaurant  \
# 1                 0                   0                    0
# 2                 0                   0                    0
# 3                 0                   1                    0
# 4                 0                   0                    0
# 5                 1                   0                    0
#
#    Korean Restaurant  Latin American Restaurant  Mediterranean Restaurant  \
# 1                  0                          0                         0
# 2                  0                          0                         0
# 3                  0                          0                         0
# 4                  0                          0                         0
# 5                  0                          0                         0
#
#    Mexican Restaurant  New American Restaurant  Restaurant  \
# 1                   0                        0           0
# 2                   0                        0           0
# 3                   0                        0           0
# 4                   0                        0           0
# 5                   0                        0           0
#
#    Seafood Restaurant  Southern / Soul Food Restaurant  Sushi Restaurant  \
# 1                   0                                0                 0
# 2                   0                                0                 0
# 3                   0                                0                 0
# 4                   0                                0                 0
# 5                   0                                0                 0
#
#    Tex-Mex Restaurant  Thai Restaurant  Vietnamese Restaurant
# 1                   0                0                      0
# 2                   0                0                      1
# 3                   0                0                      0
# 4                   0                0                      0
# 5                   0                0                      0

# %% [markdown]
# **Next, let's group rows by zip code name and by taking the mean of the frequency of occurrence of each category**

# %%
north_dfw_grouped = north_dfw_onehot.groupby('ZIP Code Name').mean().reset_index()
north_dfw_grouped
# Out:
#   ZIP Code Name  American Restaurant  Brazilian Restaurant  \
# 0         Allen             0.060000              0.040000
# 1    Carrollton             0.075472              0.037736
# 2        Frisco             0.072727              0.036364
# 3      McKinney             0.083333              0.041667
# 4         Plano             0.070270              0.037838
# 5    Richardson             0.115385              0.038462
# 6    The Colony             0.080000              0.040000
#
#    Cajun / Creole Restaurant  Chinese Restaurant  Fast Food Restaurant  \
# 0                   0.040000            0.000000              0.180000
# 1                   0.000000            0.000000              0.150943
# 2                   0.000000            0.000000              0.218182
# 3                   0.041667            0.041667              0.208333
# 4                   0.005405            0.000000              0.183784
# 5                   0.000000            0.000000              0.134615
# 6                   0.000000            0.000000              0.160000
#
#    Greek Restaurant  Italian Restaurant  Japanese Restaurant  \
# 0          0.080000            0.120000             0.000000
# 1          0.037736            0.113208             0.037736
# 2          0.072727            0.181818             0.000000
# 3          0.062500            0.104167             0.000000
# 4          0.064865            0.140541             0.021622
# 5          0.096154            0.057692             0.038462
# 6          0.040000            0.160000             0.000000
#
#    Korean Restaurant  Latin American Restaurant  Mediterranean Restaurant  \
# 0           0.040000                   0.000000                  0.040000
# 1           0.000000                   0.018868                  0.075472
# 2           0.036364                   0.000000                  0.036364
# 3           0.041667                   0.000000                  0.041667
# 4           0.000000                   0.000000                  0.075676
# 5           0.000000                   0.038462                  0.076923
# 6           0.000000                   0.000000                  0.080000
#
#    Mexican Restaurant  New American Restaurant  Restaurant  \
# 0            0.160000                 0.020000    0.000000
# 1            0.150943                 0.037736    0.056604
# 2            0.163636                 0.036364    0.000000
# 3            0.166667                 0.000000    0.000000
# 4            0.075676                 0.032432    0.032432
# 5            0.019231                 0.057692    0.057692
# 6            0.080000                 0.040000    0.040000
#
#    Seafood Restaurant  Southern / Soul Food Restaurant  Sushi Restaurant  \
# 0            0.040000                         0.020000          0.100000
# 1            0.018868                         0.037736          0.075472
# 2            0.000000                         0.036364          0.090909
# 3            0.020833                         0.041667          0.020833
# 4            0.059459                         0.027027          0.075676
# 5            0.076923                         0.000000          0.076923
# 6            0.040000                         0.040000          0.120000
#
#    Tex-Mex Restaurant  Thai Restaurant  Vietnamese Restaurant
# 0            0.000000         0.020000               0.040000
# 1            0.037736         0.037736               0.000000
# 2            0.000000         0.000000               0.018182
# 3            0.000000         0.041667               0.041667
# 4            0.032432         0.037838               0.027027
# 5            0.038462         0.057692               0.019231
# 6            0.040000         0.040000               0.000000

# %% [markdown]
# Function to sort the venues in descending order

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# New dataframe to display the top 10 venues for each neighborhood

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['ZIP Code Name']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
zip_code_name_venues_sorted = pd.DataFrame(columns=columns)
zip_code_name_venues_sorted['ZIP Code Name'] = north_dfw_grouped['ZIP Code Name']

for ind in np.arange(north_dfw_grouped.shape[0]):
    zip_code_name_venues_sorted.iloc[ind, 1:] = return_most_common_venues(north_dfw_grouped.iloc[ind, :], num_top_venues)

zip_code_name_venues_sorted
# Out:
#   ZIP Code Name 1st Most Common Venue 2nd Most Common Venue  \
# 0         Allen  Fast Food Restaurant    Mexican Restaurant
# 1    Carrollton    Mexican Restaurant  Fast Food Restaurant
# 2        Frisco  Fast Food Restaurant    Italian Restaurant
# 3      McKinney  Fast Food Restaurant    Mexican Restaurant
# 4         Plano  Fast Food Restaurant    Italian Restaurant
# 5    Richardson  Fast Food Restaurant   American Restaurant
# 6    The Colony    Italian Restaurant  Fast Food Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue     5th Most Common Venue  \
# 0    Italian Restaurant      Sushi Restaurant          Greek Restaurant
# 1    Italian Restaurant   American Restaurant          Sushi Restaurant
# 2    Mexican Restaurant      Sushi Restaurant       American Restaurant
# 3    Italian Restaurant   American Restaurant          Greek Restaurant
# 4      Sushi Restaurant    Mexican Restaurant  Mediterranean Restaurant
# 5      Greek Restaurant      Sushi Restaurant        Seafood Restaurant
# 6      Sushi Restaurant   American Restaurant        Mexican Restaurant
#
#       6th Most Common Venue 7th Most Common Venue  \
# 0       American Restaurant     Korean Restaurant
# 1  Mediterranean Restaurant            Restaurant
# 2          Greek Restaurant     Korean Restaurant
# 3           Thai Restaurant  Brazilian Restaurant
# 4       American Restaurant      Greek Restaurant
# 5  Mediterranean Restaurant            Restaurant
# 6  Mediterranean Restaurant    Tex-Mex Restaurant
#
#              8th Most Common Venue            9th Most Common Venue  \
# 0             Brazilian Restaurant        Cajun / Creole Restaurant
# 1                 Greek Restaurant               Tex-Mex Restaurant
# 2             Brazilian Restaurant  Southern / Soul Food Restaurant
# 3        Cajun / Creole Restaurant               Chinese Restaurant
# 4               Seafood Restaurant             Brazilian Restaurant
# 5          New American Restaurant                  Thai Restaurant
# 6  Southern / Soul Food Restaurant               Seafood Restaurant
#
#             10th Most Common Venue
# 0            Vietnamese Restaurant
# 1  Southern / Soul Food Restaurant
# 2          New American Restaurant
# 3                Korean Restaurant
# 4                  Thai Restaurant
# 5               Italian Restaurant
# 6                       Restaurant

# %% [markdown]
# Cluster Neighborhoods

# %%
# set number of clusters
kclusters = 7

north_dfw_grouped_clustering = north_dfw_grouped.drop('ZIP Code Name', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(north_dfw_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([5, 3, 1, 4, 0, 2, 6], dtype=int32)

# %%
# add clustering labels
zip_code_name_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

north_dfw_merged = north_dfw_df

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
north_dfw_merged = north_dfw_merged.join(zip_code_name_venues_sorted.set_index('ZIP Code Name'), on='ZIP Code Name')

north_dfw_merged # check the last columns!
# Out:
#     ZIP Code ZIP Code Name  Population State   Latitude  Longitude  \
# 0      75002         Allen     63140.0    TX  33.092846  -96.62447
# 1      75013         Allen     30347.0    TX  33.106582  -96.69402
# 2      75023         Plano     45452.0    TX  33.054671  -96.73506
# 3      75024         Plano     36039.0    TX  33.077070  -96.79859
# 4      75025         Plano     50926.0    TX  33.086868  -96.74504
# 5      75034        Frisco     72723.0    TX  33.143792  -96.83938
# 6      75035        Frisco     47553.0    TX  33.130086  -96.78177
# 7      75069      McKinney     34108.0    TX  33.195073  -96.60363
# 8      75070      McKinney     74734.0    TX  33.212203  -96.67522
# 9      75074         Plano     44622.0    TX  33.028921  -96.68102
# 10     75075         Plano     33262.0    TX  33.024721  -96.74038
# 11     75080    Richardson     44009.0    TX  32.969523  -96.74093
# 12     75082    Richardson     21182.0    TX  32.993405  -96.65901
# 13     75093         Plano     47187.0    TX  33.035050  -96.80492
# 14     75094         Plano     20579.0    TX  33.009681  -96.61113
# 15     75007    Carrollton     51624.0    TX  33.005420  -96.89773
# 16     75010    Carrollton     21607.0    TX  33.030556  -96.89328
# 17     75056    The Colony     47852.0    TX  33.081421  -96.88957
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0                5  Fast Food Restaurant    Mexican Restaurant
# 1                5  Fast Food Restaurant    Mexican Restaurant
# 2                0  Fast Food Restaurant    Italian Restaurant
# 3                0  Fast Food Restaurant    Italian Restaurant
# 4                0  Fast Food Restaurant    Italian Restaurant
# 5                1  Fast Food Restaurant    Italian Restaurant
# 6                1  Fast Food Restaurant    Italian Restaurant
# 7                4  Fast Food Restaurant    Mexican Restaurant
# 8                4  Fast Food Restaurant    Mexican Restaurant
# 9                0  Fast Food Restaurant    Italian Restaurant
# 10               0  Fast Food Restaurant    Italian Restaurant
# 11               2  Fast Food Restaurant   American Restaurant
# 12               2  Fast Food Restaurant   American Restaurant
# 13               0  Fast Food Restaurant    Italian Restaurant
# 14               0  Fast Food Restaurant    Italian Restaurant
# 15               3    Mexican Restaurant  Fast Food Restaurant
# 16               3    Mexican Restaurant  Fast Food Restaurant
# 17               6    Italian Restaurant  Fast Food Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue     5th Most Common Venue  \
# 0     Italian Restaurant      Sushi Restaurant          Greek Restaurant
# 1     Italian Restaurant      Sushi Restaurant          Greek Restaurant
# 2       Sushi Restaurant    Mexican Restaurant  Mediterranean Restaurant
# 3       Sushi Restaurant    Mexican Restaurant  Mediterranean Restaurant
# 4       Sushi Restaurant    Mexican Restaurant  Mediterranean Restaurant
# 5     Mexican Restaurant      Sushi Restaurant       American Restaurant
# 6     Mexican Restaurant      Sushi Restaurant       American Restaurant
# 7     Italian Restaurant   American Restaurant          Greek Restaurant
# 8     Italian Restaurant   American Restaurant          Greek Restaurant
# 9       Sushi Restaurant    Mexican Restaurant  Mediterranean Restaurant
# 10      Sushi Restaurant    Mexican Restaurant  Mediterranean Restaurant
# 11      Greek Restaurant      Sushi Restaurant        Seafood Restaurant
# 12      Greek Restaurant      Sushi Restaurant        Seafood Restaurant
# 13      Sushi Restaurant    Mexican Restaurant  Mediterranean Restaurant
# 14      Sushi Restaurant    Mexican Restaurant  Mediterranean Restaurant
# 15    Italian Restaurant   American Restaurant          Sushi Restaurant
# 16    Italian Restaurant   American Restaurant          Sushi Restaurant
# 17      Sushi Restaurant   American Restaurant        Mexican Restaurant
#
#        6th Most Common Venue 7th Most Common Venue  \
# 0        American Restaurant     Korean Restaurant
# 1        American Restaurant     Korean Restaurant
# 2        American Restaurant      Greek Restaurant
# 3        American Restaurant      Greek Restaurant
# 4        American Restaurant      Greek Restaurant
# 5           Greek Restaurant     Korean Restaurant
# 6           Greek Restaurant     Korean Restaurant
# 7            Thai Restaurant  Brazilian Restaurant
# 8            Thai Restaurant  Brazilian Restaurant
# 9        American Restaurant      Greek Restaurant
# 10       American Restaurant      Greek Restaurant
# 11  Mediterranean Restaurant            Restaurant
# 12  Mediterranean Restaurant            Restaurant
# 13       American Restaurant      Greek Restaurant
# 14       American Restaurant      Greek Restaurant
# 15  Mediterranean Restaurant            Restaurant
# 16  Mediterranean Restaurant            Restaurant
# 17  Mediterranean Restaurant    Tex-Mex Restaurant
#
#               8th Most Common Venue            9th Most Common Venue  \
# 0              Brazilian Restaurant        Cajun / Creole Restaurant
# 1              Brazilian Restaurant        Cajun / Creole Restaurant
# 2                Seafood Restaurant             Brazilian Restaurant
# 3                Seafood Restaurant             Brazilian Restaurant
# 4                Seafood Restaurant             Brazilian Restaurant
# 5              Brazilian Restaurant  Southern / Soul Food Restaurant
# 6              Brazilian Restaurant  Southern / Soul Food Restaurant
# 7         Cajun / Creole Restaurant               Chinese Restaurant
# 8         Cajun / Creole Restaurant               Chinese Restaurant
# 9                Seafood Restaurant             Brazilian Restaurant
# 10               Seafood Restaurant             Brazilian Restaurant
# 11          New American Restaurant                  Thai Restaurant
# 12          New American Restaurant                  Thai Restaurant
# 13               Seafood Restaurant             Brazilian Restaurant
# 14               Seafood Restaurant             Brazilian Restaurant
# 15                 Greek Restaurant               Tex-Mex Restaurant
# 16                 Greek Restaurant               Tex-Mex Restaurant
# 17  Southern / Soul Food Restaurant               Seafood Restaurant
#
#              10th Most Common Venue
# 0             Vietnamese Restaurant
# 1             Vietnamese Restaurant
# 2                   Thai Restaurant
# 3                   Thai Restaurant
# 4                   Thai Restaurant
# 5           New American Restaurant
# 6           New American Restaurant
# 7                 Korean Restaurant
# 8                 Korean Restaurant
# 9                   Thai Restaurant
# 10                  Thai Restaurant
# 11               Italian Restaurant
# 12               Italian Restaurant
# 13                  Thai Restaurant
# 14                  Thai Restaurant
# 15  Southern / Soul Food Restaurant
# 16  Southern / Soul Food Restaurant
# 17                       Restaurant

# %%
north_dfw_merged.dropna(inplace=True)

# %%
north_dfw_merged = north_dfw_merged.astype({'Cluster Labels': 'int32'})

# %% [markdown]
# Visualize the clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(north_dfw_merged['Latitude'], north_dfw_merged['Longitude'], north_dfw_merged['ZIP Code Name'], north_dfw_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#try groupby to play with restaurant 
dfw_5_zip_Venues_restaurant = north_dfw_Venues_only_restaurant.groupby(['ZIP Code Name'])['Venue Category'].apply(lambda x: x[x.str.contains('Restaurant')].count())
dfw_5_zip_Venues_restaurant_df = dfw_5_zip_Venues_restaurant.to_frame().reset_index()
dfw_5_zip_Venues_restaurant_df.columns = ['ZIP Code Name', 'Number of Restaurant']

dfw_5_zip_Venues_restaurant_df.index = np.arange(1, len(dfw_5_zip_Venues_restaurant_df)+1)

list_rest_no = dfw_5_zip_Venues_restaurant_df['Number of Restaurant'].to_list()
print (list_rest_no)
# Out:
# [50, 53, 55, 48, 185, 52, 25]

# %% [markdown]
# **Map showing radius of the clusters representing number of restaurants in each zip code**

# %%
# create map
map_restaurants10 = folium.Map(location=[latitude, longitude])

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
#rainbow = ['#00ff00', '#ff00ff','#0000ff','#ffa500' ,'#ff0000']
Districts = ['Plano', 'Frisco', 'Richardson', 'Allen', 'The Colony', 'Carrollton', 'McKinney']

# add markers to the map
for lat, lon, poi, cluster in zip(north_dfw_merged['Latitude'], north_dfw_merged['Longitude'], north_dfw_merged['ZIP Code Name'], north_dfw_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=list_rest_no[Districts.index(poi)]*0.5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_restaurants10)
       
map_restaurants10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Examine Clusters

# %%
north_dfw_merged.loc[north_dfw_merged['Cluster Labels'] == 0, north_dfw_merged.columns[[1] + list(range(5, north_dfw_merged.shape[1]))]]
# Out:
#    ZIP Code Name  Longitude  Cluster Labels 1st Most Common Venue  \
# 2          Plano  -96.73506               0  Fast Food Restaurant
# 3          Plano  -96.79859               0  Fast Food Restaurant
# 4          Plano  -96.74504               0  Fast Food Restaurant
# 9          Plano  -96.68102               0  Fast Food Restaurant
# 10         Plano  -96.74038               0  Fast Food Restaurant
# 13         Plano  -96.80492               0  Fast Food Restaurant
# 14         Plano  -96.61113               0  Fast Food Restaurant
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 2     Italian Restaurant      Sushi Restaurant    Mexican Restaurant
# 3     Italian Restaurant      Sushi Restaurant    Mexican Restaurant
# 4     Italian Restaurant      Sushi Restaurant    Mexican Restaurant
# 9     Italian Restaurant      Sushi Restaurant    Mexican Restaurant
# 10    Italian Restaurant      Sushi Restaurant    Mexican Restaurant
# 13    Italian Restaurant      Sushi Restaurant    Mexican Restaurant
# 14    Italian Restaurant      Sushi Restaurant    Mexican Restaurant
#
#        5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 2   Mediterranean Restaurant   American Restaurant      Greek Restaurant
# 3   Mediterranean Restaurant   American Restaurant      Greek Restaurant
# 4   Mediterranean Restaurant   American Restaurant      Greek Restaurant
# 9   Mediterranean Restaurant   American Restaurant      Greek Restaurant
# 10  Mediterranean Restaurant   American Restaurant      Greek Restaurant
# 13  Mediterranean Restaurant   American Restaurant      Greek Restaurant
# 14  Mediterranean Restaurant   American Restaurant      Greek Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 2     Seafood Restaurant  Brazilian Restaurant        Thai Restaurant
# 3     Seafood Restaurant  Brazilian Restaurant        Thai Restaurant
# 4     Seafood Restaurant  Brazilian Restaurant        Thai Restaurant
# 9     Seafood Restaurant  Brazilian Restaurant        Thai Restaurant
# 10    Seafood Restaurant  Brazilian Restaurant        Thai Restaurant
# 13    Seafood Restaurant  Brazilian Restaurant        Thai Restaurant
# 14    Seafood Restaurant  Brazilian Restaurant        Thai Restaurant

# %%
north_dfw_merged.loc[north_dfw_merged['Cluster Labels'] == 1, north_dfw_merged.columns[[1] + list(range(5, north_dfw_merged.shape[1]))]]
# Out:
#   ZIP Code Name  Longitude  Cluster Labels 1st Most Common Venue  \
# 5        Frisco  -96.83938               1  Fast Food Restaurant
# 6        Frisco  -96.78177               1  Fast Food Restaurant
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 5    Italian Restaurant    Mexican Restaurant      Sushi Restaurant
# 6    Italian Restaurant    Mexican Restaurant      Sushi Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 5   American Restaurant      Greek Restaurant     Korean Restaurant
# 6   American Restaurant      Greek Restaurant     Korean Restaurant
#
#   8th Most Common Venue            9th Most Common Venue  \
# 5  Brazilian Restaurant  Southern / Soul Food Restaurant
# 6  Brazilian Restaurant  Southern / Soul Food Restaurant
#
#     10th Most Common Venue
# 5  New American Restaurant
# 6  New American Restaurant

# %%
north_dfw_merged.loc[north_dfw_merged['Cluster Labels'] == 2, north_dfw_merged.columns[[1] + list(range(5, north_dfw_merged.shape[1]))]]
# Out:
#    ZIP Code Name  Longitude  Cluster Labels 1st Most Common Venue  \
# 11    Richardson  -96.74093               2  Fast Food Restaurant
# 12    Richardson  -96.65901               2  Fast Food Restaurant
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 11   American Restaurant      Greek Restaurant      Sushi Restaurant
# 12   American Restaurant      Greek Restaurant      Sushi Restaurant
#
#    5th Most Common Venue     6th Most Common Venue 7th Most Common Venue  \
# 11    Seafood Restaurant  Mediterranean Restaurant            Restaurant
# 12    Seafood Restaurant  Mediterranean Restaurant            Restaurant
#
#       8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 11  New American Restaurant       Thai Restaurant     Italian Restaurant
# 12  New American Restaurant       Thai Restaurant     Italian Restaurant

# %%
north_dfw_merged.loc[north_dfw_merged['Cluster Labels'] == 3, north_dfw_merged.columns[[1] + list(range(5, north_dfw_merged.shape[1]))]]
# Out:
#    ZIP Code Name  Longitude  Cluster Labels 1st Most Common Venue  \
# 15    Carrollton  -96.89773               3    Mexican Restaurant
# 16    Carrollton  -96.89328               3    Mexican Restaurant
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 15  Fast Food Restaurant    Italian Restaurant   American Restaurant
# 16  Fast Food Restaurant    Italian Restaurant   American Restaurant
#
#    5th Most Common Venue     6th Most Common Venue 7th Most Common Venue  \
# 15      Sushi Restaurant  Mediterranean Restaurant            Restaurant
# 16      Sushi Restaurant  Mediterranean Restaurant            Restaurant
#
#    8th Most Common Venue 9th Most Common Venue  \
# 15      Greek Restaurant    Tex-Mex Restaurant
# 16      Greek Restaurant    Tex-Mex Restaurant
#
#              10th Most Common Venue
# 15  Southern / Soul Food Restaurant
# 16  Southern / Soul Food Restaurant

# %%
north_dfw_merged.loc[north_dfw_merged['Cluster Labels'] == 4, north_dfw_merged.columns[[1] + list(range(5, north_dfw_merged.shape[1]))]]
# Out:
#   ZIP Code Name  Longitude  Cluster Labels 1st Most Common Venue  \
# 7      McKinney  -96.60363               4  Fast Food Restaurant
# 8      McKinney  -96.67522               4  Fast Food Restaurant
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 7    Mexican Restaurant    Italian Restaurant   American Restaurant
# 8    Mexican Restaurant    Italian Restaurant   American Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 7      Greek Restaurant       Thai Restaurant  Brazilian Restaurant
# 8      Greek Restaurant       Thai Restaurant  Brazilian Restaurant
#
#        8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 7  Cajun / Creole Restaurant    Chinese Restaurant      Korean Restaurant
# 8  Cajun / Creole Restaurant    Chinese Restaurant      Korean Restaurant

# %%
north_dfw_merged.loc[north_dfw_merged['Cluster Labels'] == 5, north_dfw_merged.columns[[1] + list(range(5, north_dfw_merged.shape[1]))]]
# Out:
#   ZIP Code Name  Longitude  Cluster Labels 1st Most Common Venue  \
# 0         Allen  -96.62447               5  Fast Food Restaurant
# 1         Allen  -96.69402               5  Fast Food Restaurant
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0    Mexican Restaurant    Italian Restaurant      Sushi Restaurant
# 1    Mexican Restaurant    Italian Restaurant      Sushi Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0      Greek Restaurant   American Restaurant     Korean Restaurant
# 1      Greek Restaurant   American Restaurant     Korean Restaurant
#
#   8th Most Common Venue      9th Most Common Venue 10th Most Common Venue
# 0  Brazilian Restaurant  Cajun / Creole Restaurant  Vietnamese Restaurant
# 1  Brazilian Restaurant  Cajun / Creole Restaurant  Vietnamese Restaurant

# %%
north_dfw_merged.loc[north_dfw_merged['Cluster Labels'] == 6, north_dfw_merged.columns[[1] + list(range(5, north_dfw_merged.shape[1]))]]
# Out:
#    ZIP Code Name  Longitude  Cluster Labels 1st Most Common Venue  \
# 17    The Colony  -96.88957               6    Italian Restaurant
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 17  Fast Food Restaurant      Sushi Restaurant   American Restaurant
#
#    5th Most Common Venue     6th Most Common Venue 7th Most Common Venue  \
# 17    Mexican Restaurant  Mediterranean Restaurant    Tex-Mex Restaurant
#
#               8th Most Common Venue 9th Most Common Venue  \
# 17  Southern / Soul Food Restaurant    Seafood Restaurant
#
#    10th Most Common Venue
# 17             Restaurant
